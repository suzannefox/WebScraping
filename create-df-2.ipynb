# %%
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
def parse_planet_info(text):
    """Extracts planet details from a text block."""
    planet = {}
    
    # Extract planet name and status (e.g., "HATS-6b (LOW)")
    m = re.search(r"^(\S+)\s+\(([^)]+)\)", text)
    if m:
        planet["name"] = m.group(1)
        planet["status"] = m.group(2)
    
    # Extract minimum aperture (e.g., "Min. aperture: 11.99\"")
    m = re.search(r"Min\. aperture:\s*([\d\.]+)\"", text)
    if m:
        planet["min_aperture"] = float(m.group(1))
    
    # Extract total and recent observations (e.g., "Total Observations (Recent): 36 (3)")
    m = re.search(r"Total Observations \(Recent\):\s*(\d+)\s+\((\d+)\)", text)
    if m:
        planet["total_observations"] = int(m.group(1))
        planet["recent_observations"] = int(m.group(2))
    
    # Extract O-C timing (e.g., "O-C: 3.3 ± 0.33 minutes")
    m = re.search(r"O-C:\s*([-\d\.]+\s*±\s*[\d\.]+\s*minutes)", text)
    if m:
        planet["oc"] = m.group(1)
    
    return planet

# %%
def parse_planet_row_fixed(row, observatory):
    """Extracts all information about a planet from a <tr> row, handling missing fields."""
    planet_info = {"observatory": observatory}

    # Extract all table cells in the row
    cells = row.find_all("td", style="border-right: solid 1px")
    if len(cells) < 2:
        return None

    # Planet name and status
    planet_text = cells[0].get_text(" ", strip=True)
    m = re.search(r"^(\S+)\s+\(([^)]+)\)", planet_text)
    if m:
        planet_info["name"] = m.group(1)
        planet_info["status"] = m.group(2)

    # Min aperture
    m = re.search(r"Min\. aperture:\s*([\d\.]+)\"", planet_text)
    if m:
        planet_info["min_aperture"] = float(m.group(1))

    # Observations
    m = re.search(r"Total Observations \(Recent\):\s*(\d+)\s+\((\d+)\)", planet_text)
    if m:
        planet_info["total_observations"] = int(m.group(1))
        planet_info["recent_observations"] = int(m.group(2))

    # O-C timing
    m = re.search(r"O-C:\s*([-\d\.]+\s*±\s*[\d\.]+\s*minutes)", planet_text)
    if m:
        planet_info["oc"] = m.group(1)

    # Extract second cell (position & brightness details)
    details_text = cells[1].get_text(" ", strip=True)

    m = re.search(r"RA:\s*([\d:\.]+)\s*hours", details_text)
    if m:
        planet_info["RA"] = m.group(1)

    m = re.search(r"DEC:\s*([-\d:\.]+)\s*degrees", details_text)
    if m:
        planet_info["DEC"] = m.group(1)

    m = re.search(r"MagR:\s*([\d\.]+)\s*mag", details_text)
    if m:
        planet_info["magnitude"] = float(m.group(1))

    m = re.search(r"DepthR:\s*([\d\.]+)\s*mmag", details_text)
    if m:
        planet_info["depth"] = float(m.group(1))

    m = re.search(r"Duration:\s*([\d\.]+)\s*hours", details_text)
    if m:
        planet_info["duration"] = float(m.group(1))

    # Extract transit times and altitudes from third cell (if present)
    transit_times = []
    if len(cells) > 2:
        for transit_td in cells[2].find_all("td"):
            transit_text = transit_td.get_text(" ", strip=True)
            m = re.search(r"(\d{4}/\d{2}/\d{2})\s*(\d{2}:\d{2})\s*Alt:\s*(\d+)°\s*Azi:\s*(\d+)°\s*\((\w+)\)\s*HA:\s*([\d\.]+)h", transit_text)
            if m:
                transit_times.append({
                    "date": m.group(1),
                    "time": m.group(2),
                    "altitude": int(m.group(3)),
                    "azimuth": int(m.group(4)),
                    "direction": m.group(5),
                    "hour_angle": float(m.group(6))
                })

    planet_info["transits"] = transit_times if transit_times else None

    # Extract meridian crossing, moon illumination, and moon distance (if present)
    if len(cells) > 2:
        meridian_text = cells[2].get_text(" ", strip=True)

        m = re.search(r"Meridian crossing at:\s*(\d{4}/\d{2}/\d{2} \d{2}:\d{2})", meridian_text)
        if m:
            planet_info["meridian_crossing"] = m.group(1)

        m = re.search(r"Moon illumination:\s*([\d\.]+)%", meridian_text)
        if m:
            planet_info["moon_illumination"] = float(m.group(1))

        m = re.search(r"Moon distance:\s*([\d\.]+)°", meridian_text)
        if m:
            planet_info["moon_distance"] = float(m.group(1))

    return planet_info

# %%
# Process the HTML file again with extended parsing
# Load the HTML file
file_path = "ExoClock - My Schedule - Small.html"
with open(file_path, "r", encoding="utf-8") as file:
    soup = BeautifulSoup(file, "html.parser")

# Extract observatories and their corresponding planets
extended_data = []
observatories = soup.find_all("h4")

for observatory in observatories:
    obs_name = observatory.text.strip()
    table = observatory.find_next("table")
    if not table:
        continue
    
    i = 0  
    for row in table.find_all("tr", style="border-bottom: dotted 1px"):
        print(observatory, row)
        x = parse_planet_row_fixed(row, obs_name)
        for y in x:
            print(y)
        print(i, x)
        if i == 0:
            break
        # if planet_cell:
        #     planet_info = parse_planet_info(planet_cell.get_text(" ", strip=True))
        #     if planet_info:
        #         planet_info["observatory"] = obs_name  # Add observatory name
        #         extended_data.append(planet_info)

# Convert to DataFrame
# df_extended = pd.DataFrame(extended_data)
# Out:
# <h4>Haleakala Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS</h4> <tr style="border-bottom: dotted 1px"><td style="border-right: solid 1px" width="200px"><a href="https://www.exoclock.space/database/planets/HATS-6b" target="_blank"><font style="color:#94420c; font-size:1.5em">HATS-6b</font></a> (<a data-target="#priorities" data-toggle="modal" href="https://www.exoclock.space/schedule/100#priorities"><font color="green">LOW</font></a>)<br/>Min. aperture: 11.99"<br/>Total Observations (Recent): 36 (3)<br/>O-C: 3.3 ± 0.33 minutes</td><td style="border-right: solid 1px" width="300px"> RA: 05:52:35.2366 hours (J2000)<br/>DEC: -19:01:53.970 degrees (J2000)<br/>Mag<sub>R</sub>: 14.139 mag<br/>Depth<sub>R</sub>: 41.78 mmag<br/>Duration: 2.05 hours</td><td><table cellpadding="5" class="text-center" width="100%"><tbody><tr><td><font color="black">2025/02/17<br/>06:04<br/>Alt: 50°<br/>Azi: 172° (S)<br/>HA: 23.62h</font></td><td><font color="black">2025/02/17<br/>07:04<br/>Alt: 49°<br/>Azi: 194° (S)<br/>HA: 0.62h</font></td><td><font color="black">2025/02/17<br/>08:06<br/>Alt: 44°<br/>Azi: 213° (SW)<br/>HA: 1.65h</font></td><td><font color="black">2025/02/17<br/>09:07<br/>Alt: 34°<br/>Azi: 227° (SW)<br/>HA: 2.68h</font></td><td><a data-target="#no-after-target" data-toggle="modal" href="https://www.exoclock.space/schedule/100#no-after-target"><u><font color="red">2025/02/17<br/>10:07<br/>Alt: 23°<br/>Azi: 237° (SW)<br/>HA: 3.68h</font></u></a></td></tr><tr><td colspan="5">Meridian crossing at: 2025/02/17 06:30<br/><a data-target="#max-counts" data-toggle="modal" href="https://www.exoclock.space/schedule/100#max-counts"><u>Max counts increase during observation</u></a>: <b>R:0%</b> <b>V:0%</b><br/>Moon illumination: <b>80.1%</b>, Moon distance: <b>106.0°</b></td></tr></tbody></table></td></tr>
# observatory
# name
# status
# min_aperture
# total_observations
# recent_observations
# oc
# RA
# DEC
# duration
# transits
# 0 {'observatory': 'Haleakala Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS', 'name': 'HATS-6b', 'status': ' LOW ', 'min_aperture': 11.99, 'total_observations': 36, 'recent_observations': 3, 'oc': '3.3 ± 0.33 minutes', 'RA': '05:52:35.2366', 'DEC': '-19:01:53.970', 'duration': 2.05, 'transits': None}
# <h4>McDonald Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS</h4> <tr style="border-bottom: dotted 1px"><td style="border-right: solid 1px" width="200px"><a href="https://www.exoclock.space/database/planets/HAT-P-61b" target="_blank"><font style="color:#94420c; font-size:1.5em">HAT-P-61b</font></a> (<a data-target="#priorities" data-toggle="modal" href="https://www.exoclock.space/schedule/100#priorities"><font color="green">LOW</font></a>)<br/>Min. aperture: 11.09"<br/>Total Observations (Recent): 56 (21)<br/>O-C: 1.01 ± 0.3 minutes</td><td style="border-right: solid 1px" width="300px"> RA: 05:01:55.2577 hours (J2000)<br/>DEC: +50:07:52.574 degrees (J2000)<br/>Mag<sub>R</sub>: 12.974 mag<br/>Depth<sub>R</sub>: 10.41 mmag<br/>Duration: 1.67 hours</td><td><table cellpadding="5" class="text-center" width="100%"><tbody><tr><td><font color="black">2025/02/17<br/>02:59<br/>Alt: 68°<br/>Azi: 338° (N)<br/>HA: 0.85h</font></td><td><font color="black">2025/02/17<br/>03:59<br/>Alt: 62°<br/>Azi: 321° (NW)<br/>HA: 1.85h</font></td><td><font color="black">2025/02/17<br/>04:49<br/>Alt: 54°<br/>Azi: 315° (NW)<br/>HA: 2.69h</font></td><td><font color="black">2025/02/17<br/>05:39<br/>Alt: 46°<br/>Azi: 312° (NW)<br/>HA: 3.53h</font></td><td><font color="black">2025/02/17<br/>06:39<br/>Alt: 37°<br/>Azi: 312° (NW)<br/>HA: 4.53h</font></td></tr><tr><td colspan="5"><a data-target="#max-counts" data-toggle="modal" href="https://www.exoclock.space/schedule/100#max-counts"><u>Max counts increase during observation</u></a>: <b>R:0%</b> <b>V:0%</b><br/>Moon illumination: <b>81.1%</b>, Moon distance: <b>117.8°</b></td></tr></tbody></table></td></tr>
# observatory
# name
# status
# min_aperture
# total_observations
# recent_observations
# oc
# RA
# duration
# transits
# 0 {'observatory': 'McDonald Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS', 'name': 'HAT-P-61b', 'status': ' LOW ', 'min_aperture': 11.09, 'total_observations': 56, 'recent_observations': 21, 'oc': '1.01 ± 0.3 minutes', 'RA': '05:01:55.2577', 'duration': 1.67, 'transits': None}
# <h4>Teide Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS</h4> <tr style="border-bottom: dotted 1px"><td style="border-right: solid 1px" width="200px"><a href="https://www.exoclock.space/database/planets/TOI-2587Ab" target="_blank"><font style="color:#94420c; font-size:1.5em">TOI-2587Ab</font></a> (<a data-target="#priorities" data-toggle="modal" href="https://www.exoclock.space/schedule/100#priorities"><font color="red">HIGH</font></a>)<br/>Min. aperture: 11.9"<br/>Total Observations (Recent): 0 (0)<br/>O-C: -</td><td style="border-right: solid 1px" width="300px"> RA: 07:43:43.5877 hours (J2000)<br/>DEC: -01:04:23.606 degrees (J2000)<br/>Mag<sub>R</sub>: 11.184 mag<br/>Depth<sub>R</sub>: 4.6 mmag<br/>Duration: 4.17 hours</td><td><table cellpadding="5" class="text-center" width="100%"><tbody><tr><td><font color="black">2025/02/16<br/>20:47<br/>Alt: 47°<br/>Azi: 127° (SE)<br/>HA: 21.77h</font></td><td><font color="black">2025/02/16<br/>21:47<br/>Alt: 56°<br/>Azi: 146° (SE)<br/>HA: 22.78h</font></td><td><font color="black">2025/02/16<br/>23:52<br/>Alt: 58°<br/>Azi: 205° (SW)<br/>HA: 0.87h</font></td><td><font color="black">2025/02/17<br/>01:57<br/>Alt: 38°<br/>Azi: 243° (SW)<br/>HA: 2.96h</font></td><td><a data-target="#no-after-target" data-toggle="modal" href="https://www.exoclock.space/schedule/100#no-after-target"><u><font color="red">2025/02/17<br/>02:57<br/>Alt: 26°<br/>Azi: 253° (W)<br/>HA: 3.96h</font></u></a></td></tr><tr><td colspan="5">Meridian crossing at: 2025/02/16 23:00<br/><a data-target="#max-counts" data-toggle="modal" href="https://www.exoclock.space/schedule/100#max-counts"><u>Max counts increase during observation</u></a>: <b>R:2%</b> <b>V:4%</b><br/>Moon illumination: <b>82.6%</b>, Moon distance: <b>79.6°</b></td></tr></tbody></table></td></tr>
# observatory
# name
# status
# min_aperture
# total_observations
# recent_observations
# RA
# DEC
# duration
# transits
# 0 {'observatory': 'Teide Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS', 'name': 'TOI-2587Ab', 'status': ' HIGH ', 'min_aperture': 11.9, 'total_observations': 0, 'recent_observations': 0, 'RA': '07:43:43.5877', 'DEC': '-01:04:23.606', 'duration': 4.17, 'transits': None}
# <h4>Siding Spring Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS</h4> <tr style="border-bottom: dotted 1px"><td style="border-right: solid 1px" width="200px"><a href="https://www.exoclock.space/database/planets/HATS-31b" target="_blank"><font style="color:#94420c; font-size:1.5em">HATS-31b</font></a> (<a data-target="#priorities" data-toggle="modal" href="https://www.exoclock.space/schedule/100#priorities"><font color="orange">MEDIUM</font></a>)<br/>Min. aperture: 9.75"<br/>Total Observations (Recent): 8 (2)<br/>O-C: 1.28 ± 1.46 minutes</td><td style="border-right: solid 1px" width="300px"> RA: 12:46:48.6784 hours (J2000)<br/>DEC: -24:25:38.568 degrees (J2000)<br/>Mag<sub>R</sub>: 13.2 mag<br/>Depth<sub>R</sub>: 10.34 mmag<br/>Duration: 4.64 hours</td><td><table cellpadding="5" class="text-center" width="100%"><tbody><tr> <td colspan="5"><b>OBSERVATION HAS STARTED!</b></td></tr><tr><td><font color="black">2025/02/16<br/>12:35<br/>Alt: 31°<br/>Azi: 101° (E)<br/>HA: 19.53h</font></td><td><font color="black">2025/02/16<br/>13:35<br/>Alt: 44°<br/>Azi: 95° (E)<br/>HA: 20.54h</font></td><td><font color="black">2025/02/16<br/>15:55<br/>Alt: 73°<br/>Azi: 70° (E)<br/>HA: 22.86h</font></td><td><font color="black">2025/02/16<br/>18:14<br/>Alt: 73°<br/>Azi: 289° (W)<br/>HA: 1.19h</font></td><td><a data-target="#no-after-sun" data-toggle="modal" href="https://www.exoclock.space/schedule/100#no-after-sun"><u><font color="red">2025/02/16<br/>19:14<br/>Alt: 60°<br/>Azi: 275° (W)<br/>HA: 2.19h</font></u></a></td></tr><tr><td colspan="5">Meridian crossing at: 2025/02/16 17:05<br/><a data-target="#max-counts" data-toggle="modal" href="https://www.exoclock.space/schedule/100#max-counts"><u>Max counts increase during observation</u></a>: <b>R:9%</b> <b>V:19%</b><br/>Moon illumination: <b>84.9%</b>, Moon distance: <b>17.7°</b></td></tr></tbody></table></td></tr>
# observatory
# name
# status
# min_aperture
# total_observations
# recent_observations
# oc
# RA
# DEC
# duration
# transits
# 0 {'observatory': 'Siding Spring Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS', 'name': 'HATS-31b', 'status': ' MEDIUM ', 'min_aperture': 9.75, 'total_observations': 8, 'recent_observations': 2, 'oc': '1.28 ± 1.46 minutes', 'RA': '12:46:48.6784', 'DEC': '-24:25:38.568', 'duration': 4.64, 'transits': None}
# <h4>Sutherland Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS</h4> <tr style="border-bottom: dotted 1px"><td style="border-right: solid 1px" width="200px"><a href="https://www.exoclock.space/database/planets/TOI-674b" target="_blank"><font style="color:#94420c; font-size:1.5em">TOI-674b</font></a> (<a data-target="#priorities" data-toggle="modal" href="https://www.exoclock.space/schedule/100#priorities"><font color="orange">MEDIUM</font></a>)<br/>Min. aperture: 11.86"<br/>Total Observations (Recent): 43 (2)<br/>O-C: 0.71 ± 0.39 minutes</td><td style="border-right: solid 1px" width="300px"> RA: 10:58:20.9850 hours (J2000)<br/>DEC: -36:51:29.134 degrees (J2000)<br/>Mag<sub>R</sub>: 13.914 mag<br/>Depth<sub>R</sub>: 15.57 mmag<br/>Duration: 1.09 hours</td><td><table cellpadding="5" class="text-center" width="100%"><tbody><tr> <td colspan="5"><b>OBSERVATION HAS STARTED!</b></td></tr><tr><td><font color="black">2025/02/16<br/>18:58<br/>Alt: 32°<br/>Azi: 116° (SE)<br/>HA: 19.19h</font></td><td><font color="black">2025/02/16<br/>19:58<br/>Alt: 43°<br/>Azi: 112° (E)<br/>HA: 20.19h</font></td><td><font color="black">2025/02/16<br/>20:30<br/>Alt: 50°<br/>Azi: 110° (E)<br/>HA: 20.74h</font></td><td><font color="black">2025/02/16<br/>21:03<br/>Alt: 56°<br/>Azi: 109° (E)<br/>HA: 21.28h</font></td><td><font color="black">2025/02/16<br/>22:03<br/>Alt: 68°<br/>Azi: 109° (E)<br/>HA: 22.28h</font></td></tr><tr><td colspan="5"><a data-target="#max-counts" data-toggle="modal" href="https://www.exoclock.space/schedule/100#max-counts"><u>Max counts increase during observation</u></a>: <b>R:8%</b> <b>V:16%</b><br/>Moon illumination: <b>83.6%</b>, Moon distance: <b>39.5°</b></td></tr></tbody></table></td></tr>
# observatory
# name
# status
# min_aperture
# total_observations
# recent_observations
# oc
# RA
# DEC
# duration
# transits
# 0 {'observatory': 'Sutherland Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS', 'name': 'TOI-674b', 'status': ' MEDIUM ', 'min_aperture': 11.86, 'total_observations': 43, 'recent_observations': 2, 'oc': '0.71 ± 0.39 minutes', 'RA': '10:58:20.9850', 'DEC': '-36:51:29.134', 'duration': 1.09, 'transits': None}
# <h4>Cerro Tololo Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS</h4> <tr style="border-bottom: dotted 1px"><td style="border-right: solid 1px" width="200px"><a href="https://www.exoclock.space/database/planets/CoRoT-5b" target="_blank"><font style="color:#94420c; font-size:1.5em">CoRoT-5b</font></a> (<a data-target="#priorities" data-toggle="modal" href="https://www.exoclock.space/schedule/100#priorities"><font color="green">LOW</font></a>)<br/>Min. aperture: 10.62"<br/>Total Observations (Recent): 11 (3)<br/>O-C: 5.92 ± 1.34 minutes</td><td style="border-right: solid 1px" width="300px"> RA: 06:45:06.5406 hours (J2000)<br/>DEC: +00:48:54.905 degrees (J2000)<br/>Mag<sub>R</sub>: 13.82 mag<br/>Depth<sub>R</sub>: 14.93 mmag<br/>Duration: 2.77 hours</td><td><table cellpadding="5" class="text-center" width="100%"><tbody><tr><td><a data-target="#no-pre-sun" data-toggle="modal" href="https://www.exoclock.space/schedule/100#no-pre-sun"><u><font color="red">2025/02/16<br/>23:18<br/>Alt: 44°<br/>Azi: 54° (NE)<br/>HA: 21.64h</font></u></a></td><td><font color="black">2025/02/17<br/>00:18<br/>Alt: 53°<br/>Azi: 36° (NE)<br/>HA: 22.65h</font></td><td><font color="black">2025/02/17<br/>01:41<br/>Alt: 59°<br/>Azi: 359° (N)<br/>HA: 0.04h</font></td><td><font color="black">2025/02/17<br/>03:04<br/>Alt: 53°<br/>Azi: 323° (NW)<br/>HA: 1.42h</font></td><td><font color="black">2025/02/17<br/>04:04<br/>Alt: 43°<br/>Azi: 305° (NW)<br/>HA: 2.43h</font></td></tr><tr><td colspan="5">Meridian crossing at: 2025/02/17 01:38<br/><a data-target="#max-counts" data-toggle="modal" href="https://www.exoclock.space/schedule/100#max-counts"><u>Max counts increase during observation</u></a>: <b>R:3%</b> <b>V:5%</b><br/>Moon illumination: <b>82.1%</b>, Moon distance: <b>95.1°</b></td></tr></tbody></table></td></tr>
# observatory
# name
# status
# min_aperture
# total_observations
# recent_observations
# oc
# RA
# duration
# transits
# 0 {'observatory': 'Cerro Tololo Observatory - PlaneWave Delta Rho 350 - QHY600 CMOS', 'name': 'CoRoT-5b', 'status': ' LOW ', 'min_aperture': 10.62, 'total_observations': 11, 'recent_observations': 3, 'oc': '5.92 ± 1.34 minutes', 'RA': '06:45:06.5406', 'duration': 2.77, 'transits': None}
# <h4>Nostos Observatory - Celestron C9.25 - ZWO - ASI533MC Pro Colour</h4> <tr style="border-bottom: dotted 1px"><td style="border-right: solid 1px" width="200px"><a href="https://www.exoclock.space/database/planets/TOI-4145Ab" target="_blank"><font style="color:#94420c; font-size:1.5em">TOI-4145Ab</font></a> (<a data-target="#priorities" data-toggle="modal" href="https://www.exoclock.space/schedule/100#priorities"><font color="green">LOW</font></a>)<br/>Min. aperture: 5.39"<br/>Total Observations (Recent): 38 (25)<br/>O-C: 0.77 ± 0.2 minutes</td><td style="border-right: solid 1px" width="300px"> RA: 02:37:43.0668 hours (J2000)<br/>DEC: +80:16:02.791 degrees (J2000)<br/>Mag<sub>R</sub>: 11.808 mag<br/>Depth<sub>R</sub>: 20.81 mmag<br/>Duration: 2.1 hours</td><td><table cellpadding="5" class="text-center" width="100%"><tbody><tr> <td colspan="5"><b>OBSERVATION HAS STARTED!</b></td></tr><tr><td><a data-target="#no-pre-sun" data-toggle="modal" href="https://www.exoclock.space/schedule/100#no-pre-sun"><u><font color="red">2025/02/16<br/>15:54<br/>Alt: 47°<br/>Azi: 357° (N)<br/>HA: 0.81h</font></u></a></td><td><font color="black">2025/02/16<br/>16:54<br/>Alt: 46°<br/>Azi: 354° (N)<br/>HA: 1.81h</font></td><td><font color="black">2025/02/16<br/>17:57<br/>Alt: 44°<br/>Azi: 351° (N)<br/>HA: 2.86h</font></td><td><font color="black">2025/02/16<br/>19:00<br/>Alt: 42°<br/>Azi: 349° (N)<br/>HA: 3.92h</font></td><td><font color="black">2025/02/16<br/>20:00<br/>Alt: 40°<br/>Azi: 348° (N)<br/>HA: 4.92h</font></td></tr><tr><td colspan="5"><a data-target="#max-counts" data-toggle="modal" href="https://www.exoclock.space/schedule/100#max-counts"><u>Max counts increase during observation</u></a>: <b>R:0%</b> <b>V:0%</b><br/>Moon illumination: <b>84.3%</b>, Moon distance: <b>105.9°</b></td></tr></tbody></table></td></tr>
# observatory
# name
# status
# min_aperture
# total_observations
# recent_observations
# oc
# RA
# duration
# transits
# 0 {'observatory': 'Nostos Observatory - Celestron C9.25 - ZWO - ASI533MC Pro Colour', 'name': 'TOI-4145Ab', 'status': ' LOW ', 'min_aperture': 5.39, 'total_observations': 38, 'recent_observations': 25, 'oc': '0.77 ± 0.2 minutes', 'RA': '02:37:43.0668', 'duration': 2.1, 'transits': None}

# %%
# Process the HTML file again with extended parsing
# Load the HTML file
file_path = "ExoClock - My Schedule - Small.html"
with open(file_path, "r", encoding="utf-8") as file:
    soup = BeautifulSoup(file, "html.parser")

# Extract observatories and their corresponding planets
extended_data = []
observatories = soup.find_all("h4")

for observatory in observatories:
    obs_name = observatory.text.strip()
    table = observatory.find_next("table")
    if not table:
        continue
    
    for row in table.find_all("tr", style="border-bottom: dotted 1px"):
        planet_cell = row.find("td", style="border-right: solid 1px")
        if planet_cell:
            planet_info = parse_planet_info(planet_cell.get_text(" ", strip=True))
            if planet_info:
                planet_info["observatory"] = obs_name  # Add observatory name
                extended_data.append(planet_info)

# Convert to DataFrame
df_extended = pd.DataFrame(extended_data)

# %%
df_extended.columns
# Out:
# Index(['name', 'status', 'min_aperture', 'total_observations',
#        'recent_observations', 'oc', 'observatory'],
#       dtype='object')
